# %%
# %cd /content/MEMTO

# !mkdir -p dataset

# !wget "https://drive.usercontent.google.com/download?id=14STjpszyi6D0B7BUHZ1L4GLUkhhPXE0G&confirm=t" -O dataset/MSL.zip

# !unzip -o dataset/MSL.zip -d dataset/
# Out:
# [Errno 2] No such file or directory: '/content/MEMTO'
# /Users/muaaz/Downloads/MEMTO
# zsh:1: command not found: wget
# unzip:  cannot find or open dataset/MSL.zip, dataset/MSL.zip.zip or dataset/MSL.zip.ZIP.
