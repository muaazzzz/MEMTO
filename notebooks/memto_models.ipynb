# %%
# Clone the repository
# !git clone https://github.com/muaazzzz/MEMTO.git
# %cd MEMTO

# Install the required dependencies
# !pip install kmeans-pytorch

# !pip install "numpy<2.0"
# Out:
# Cloning into 'MEMTO'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 104 (delta 21), reused 21 (delta 17), pack-reused 66 (from 3)
# Receiving objects: 100% (104/104), 127.93 MiB | 26.95 MiB/s, done.
# Resolving deltas: 100% (36/36), done.
# /content/MEMTO
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 92.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# %cd /content
# !rm -rf MEMTO
# Out:
# /content

# %%
# %cd /content/MEMTO

# !mkdir -p dataset

# !wget "https://drive.usercontent.google.com/download?id=14STjpszyi6D0B7BUHZ1L4GLUkhhPXE0G&confirm=t" -O dataset/MSL.zip

# !unzip -o dataset/MSL.zip -d dataset/
# Out:
# /content/MEMTO
# --2026-05-07 09:38:02--  https://drive.usercontent.google.com/download?id=14STjpszyi6D0B7BUHZ1L4GLUkhhPXE0G&confirm=t
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 64.233.170.132, 2404:6800:4003:c1a::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|64.233.170.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 767283 (749K) [application/octet-stream]
# Saving to: ‘dataset/MSL.zip’
#
# dataset/MSL.zip     100%[===================>] 749.30K  --.-KB/s    in 0.01s
#
# 2026-05-07 09:38:04 (60.8 MB/s) - ‘dataset/MSL.zip’ saved [767283/767283]
#
# Archive:  dataset/MSL.zip
#    creating: dataset/MSL/
#   inflating: dataset/MSL/.DS_Store
#   inflating: dataset/MSL/MSL_test_label.npy
#   inflating: dataset/MSL/MSL_train.npy
#   inflating: dataset/MSL/MSL_test.npy

# %%
# !python main.py --dataset MSL --data_path ./dataset/MSL --input_c 55 --output_c 55 --mode train
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/MSL
# dataset: MSL
# device: cuda:0
# input_c: 55
# k: 5
# lambd: 0.01
# lr: 0
# memory_initial: False
# mode: train
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 55
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# loading memory item with random initilzation (for first train phase)
# ======================TRAIN MODE======================
#   0% 0/10 [00:00<?, ?it/s]Epoch: 1 cost time: 1.5424315929412842
# Epoch: 1, Steps: 59 | Train Loss: 0.9705462 Vali Loss: 0.6127779
# Epoch: 1, Steps: 59 | VALID reconstruction Loss: 1.8024424 Entropy loss Loss: 0.5947535
# Epoch: 1, Steps: 59 | TRAIN reconstruction Loss: 1.4644736 Entropy loss Loss: 0.9559016
# ...

# %%
# !python main.py --dataset MSL --data_path ./dataset/MSL --input_c 55 --output_c 55 --mode memory_initial
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/MSL
# dataset: MSL
# device: cuda:0
# input_c: 55
# k: 5
# lambd: 0.01
# lr: 1e-05
# memory_initial: False
# mode: memory_initial
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 55
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# loading memory item with random initilzation (for first train phase)
# running K Means Clustering. It takes few minutes to find clusters
# running k-means on cuda:0..
# [running kmeans]: 15it [00:22,  1.49s/it, center_shift=0.000000, iteration=15, tol=0.000100]
# K-means failed with error: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!. Using random initialization instead.
# ...

# %%
# !python main.py --dataset MSL --data_path ./dataset/MSL --input_c 55 --output_c 55 --mode test --anormly_ratio 0.03
# Out:
# ------------ Options -------------
# anormly_ratio: 0.03
# batch_size: 8
# d_model: 512
# data_path: ./dataset/MSL
# dataset: MSL
# device: cuda:0
# input_c: 55
# k: 5
# lambd: 0.01
# lr: 1e-05
# memory_initial: False
# mode: test
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 55
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (73729, 55)
# train: (58317, 55)
# test: (73729, 55)
# train: (58317, 55)
# ./memory_item/MSL_memory_item.pth
# loading memory item vectors trained from kmeans (for test phase)
# Loading checkpoint: checkpoints/MSL_checkpoint_second_train.pth
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
# ...

# %%
# %cd /content/MEMTO

# !gdown --folder https://drive.google.com/drive/folders/1gisthCoE-RrKJ0j3KPV7xiibhHWT9qRm -O dataset/

# !unzip -o dataset/Anomaly_Transformer/SMAP.zip -d dataset/
# Out:
# /content/MEMTO
# Retrieving folder contents
# Processing file 1BGeu0yiV4T_nsI1G2ayuGfLjIKw9ArZ_ MSL.zip
# Processing file 1kohMqejb7f787XtpM4b5HR7G22nH-rEF PSM.zip
# Processing file 1DRj6A4wFGx7SNEalGkEPzRi8Td8RdEK1 SMAP.zip
# Processing file 187cjlXCedf4v3-Xm-fK7iTQZ6k6BFaDK SMD.zip
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1BGeu0yiV4T_nsI1G2ayuGfLjIKw9ArZ_
# To: /content/MEMTO/dataset/Anomaly_Transformer/MSL.zip
# 100% 767k/767k [00:00<00:00, 9.32MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1kohMqejb7f787XtpM4b5HR7G22nH-rEF
# From (redirected): https://drive.google.com/uc?id=1kohMqejb7f787XtpM4b5HR7G22nH-rEF&confirm=t&uuid=b3b19250-ae0a-4562-97f8-260a60f6ee33
# To: /content/MEMTO/dataset/Anomaly_Transformer/PSM.zip
# 100% 38.5M/38.5M [00:01<00:00, 38.1MB/s]
# Downloading...
# ...

# %%
# Phase 1: Initial training
# !python main.py --dataset SMAP --data_path ./dataset/SMAP --input_c 25 --output_c 25 --mode train
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/SMAP
# dataset: SMAP
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 1e-05
# memory_initial: False
# mode: train
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# loading memory item with random initilzation (for first train phase)
# ======================TRAIN MODE======================
#   0% 0/10 [00:00<?, ?it/s]	speed: 0.0180s/iter; left time: 22.7373s
# Epoch: 1 cost time: 2.318459987640381
# Epoch: 1, Steps: 136 | Train Loss: 1.0010676 Vali Loss: 0.6111938
# Epoch: 1, Steps: 136 | VALID reconstruction Loss: 1.5951194 Entropy loss Loss: 0.5952427
# ...

# %%
# Phase 2: Memory initialization with K-means
# !python main.py --dataset SMAP --data_path ./dataset/SMAP --input_c 25 --output_c 25 --mode memory_initial
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/SMAP
# dataset: SMAP
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 1e-05
# memory_initial: False
# mode: memory_initial
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# loading memory item with random initilzation (for first train phase)
# running K Means Clustering. It takes few minutes to find clusters
# running k-means on cuda:0..
# [running kmeans]: 29it [01:49,  3.78s/it, center_shift=0.000000, iteration=29, tol=0.000100]
# K-means failed with error: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!. Using random initialization instead.
# ...

# %%
# Phase 3: Test with anomaly detection
# !python main.py --dataset SMAP --data_path ./dataset/SMAP --input_c 25 --output_c 25 --mode test --anormly_ratio 0.05
# Out:
# ------------ Options -------------
# anormly_ratio: 0.05
# batch_size: 8
# d_model: 512
# data_path: ./dataset/SMAP
# dataset: SMAP
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 1e-05
# memory_initial: False
# mode: test
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (427617, 25)
# train: (135183, 25)
# test: (427617, 25)
# train: (135183, 25)
# ./memory_item/SMAP_memory_item.pth
# loading memory item vectors trained from kmeans (for test phase)
# Loading checkpoint: checkpoints/SMAP_checkpoint_second_train.pth
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
# ...

# %%
# 1. Unzip the PSM dataset into the main dataset folder
# !unzip -o dataset/Anomaly_Transformer/PSM.zip -d dataset/
# Out:
# Archive:  dataset/Anomaly_Transformer/PSM.zip
#    creating: dataset/PSM/
#   inflating: dataset/PSM/test_label.csv
#   inflating: dataset/__MACOSX/PSM/._test_label.csv
#   inflating: dataset/PSM/test.csv
#   inflating: dataset/__MACOSX/PSM/._test.csv
#   inflating: dataset/PSM/train.csv
#   inflating: dataset/__MACOSX/PSM/._train.csv

# %%
# 2. Train the model on PSM
# !python main.py --dataset PSM --data_path ./dataset/PSM --input_c 25 --output_c 25 --mode train
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/PSM
# dataset: PSM
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: train
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# loading memory item with random initilzation (for first train phase)
# ======================TRAIN MODE======================
#   0% 0/10 [00:00<?, ?it/s]	speed: 0.0280s/iter; left time: 34.4933s
# Epoch: 1 cost time: 3.2646913528442383
# Epoch: 1, Steps: 133 | Train Loss: 0.2787502 Vali Loss: 0.1348365
# Epoch: 1, Steps: 133 | VALID reconstruction Loss: 4.8520303 Entropy loss Loss: 0.0863162
# ...

# %%
# !python main.py --dataset PSM --data_path ./dataset/PSM --input_c 25 --output_c 25 --mode memory_initial
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 8
# d_model: 512
# data_path: ./dataset/PSM
# dataset: PSM
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: memory_initial
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# loading memory item with random initilzation (for first train phase)
# running K Means Clustering. It takes few minutes to find clusters
# running k-means on cuda:0..
# [running kmeans]: 32it [01:47,  3.35s/it, center_shift=0.000000, iteration=32, tol=0.000100]
# K-means failed with error: Expected all tensors to be on the same device, but found at least two devices, cuda:0 and cpu!. Using random initialization instead.
# ...

# %%
# 4. Test the model
# !python main.py --dataset PSM --data_path ./dataset/PSM --input_c 25 --output_c 25 --mode test --anormly_ratio 0.02
# Out:
# ------------ Options -------------
# anormly_ratio: 0.02
# batch_size: 8
# d_model: 512
# data_path: ./dataset/PSM
# dataset: PSM
# device: cuda:0
# input_c: 25
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: test
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 25
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (87841, 25)
# train: (132481, 25)
# test: (87841, 25)
# train: (132481, 25)
# ./memory_item/PSM_memory_item.pth
# loading memory item vectors trained from kmeans (for test phase)
# Loading checkpoint: checkpoints/PSM_checkpoint_second_train.pth
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
# ...

# %%
# unzip smd data
# !unzip -o dataset/Anomaly_Transformer/SMD.zip -d dataset/
# Out:
# Archive:  dataset/Anomaly_Transformer/SMD.zip
#    creating: dataset/SMD/
#   inflating: dataset/SMD/SMD_test.npy
#   inflating: dataset/__MACOSX/SMD/._SMD_test.npy
#   inflating: dataset/SMD/SMD_test_label.pkl
#   inflating: dataset/__MACOSX/SMD/._SMD_test_label.pkl
#   inflating: dataset/SMD/SMD_train.npy
#   inflating: dataset/__MACOSX/SMD/._SMD_train.npy
#   inflating: dataset/SMD/SMD_test.pkl
#   inflating: dataset/__MACOSX/SMD/._SMD_test.pkl
#   inflating: dataset/SMD/SMD_test_label.npy
#   inflating: dataset/__MACOSX/SMD/._SMD_test_label.npy
#   inflating: dataset/SMD/SMD_train.pkl
#   inflating: dataset/__MACOSX/SMD/._SMD_train.pkl

# %%
import os
os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"

# %%
# Phase 1: Initial training on SMD
# !python main.py --dataset SMD --data_path ./dataset/SMD --input_c 38 --output_c 38 --batch_size 2 --d_model 128 --num_epochs 8 --mode train
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 2
# d_model: 128
# data_path: ./dataset/SMD
# dataset: SMD
# device: cuda:0
# input_c: 38
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: train
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 8
# num_workers: 4
# output_c: 38
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (708420, 38)
# train: (708405, 38)
# test: (708420, 38)
# train: (708405, 38)
# loading memory item with random initilzation (for first train phase)
# ======================TRAIN MODE======================
#   0% 0/8 [00:00<?, ?it/s]	speed: 0.0295s/iter; left time: 666.6372s
# 	speed: 0.0113s/iter; left time: 254.1667s
# 	speed: 0.0113s/iter; left time: 253.5745s
# 	speed: 0.0116s/iter; left time: 258.1139s
# 	speed: 0.0118s/iter; left time: 262.6899s
# 	speed: 0.0137s/iter; left time: 301.8553s
# ...

# %%
# Phase 2: Memory initialization with K-means
# !python main.py --dataset SMD --data_path ./dataset/SMD --input_c 38 --output_c 38 --batch_size 2 --d_model 128 --num_epochs 5 --mode memory_initial
# Out:
# ------------ Options -------------
# anormly_ratio: 0.0
# batch_size: 2
# d_model: 128
# data_path: ./dataset/SMD
# dataset: SMD
# device: cuda:0
# input_c: 38
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: memory_initial
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 5
# num_workers: 4
# output_c: 38
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (708420, 38)
# train: (708405, 38)
# test: (708420, 38)
# train: (708405, 38)
# loading memory item with random initilzation (for first train phase)
# running K Means Clustering. It takes few minutes to find clusters
# K-means failed with error: Bypassing K-Means to prevent System RAM crash!. Using random initialization instead.
# time for conducting Kmeans Clustering : 0.06192445755004883
# K means clustering is done!!!
# second training (for second train phase)
# ...

# %%
# Phase 3: Test the model
# !python main.py --dataset SMD --data_path ./dataset/SMD --input_c 38 --output_c 38 --batch_size 2 --d_model 128 --mode test --anormly_ratio 0.03
# Out:
# ------------ Options -------------
# anormly_ratio: 0.03
# batch_size: 2
# d_model: 128
# data_path: ./dataset/SMD
# dataset: SMD
# device: cuda:0
# input_c: 38
# k: 5
# lambd: 0.01
# lr: 0.0001
# memory_initial: False
# mode: test
# model_save_path: checkpoints
# n_memory: 128
# num_epochs: 10
# num_workers: 4
# output_c: 38
# phase_type: None
# pretrained_model: None
# temp_param: 0.05
# temperature: 0.1
# win_size: 100
# -------------- End ----------------
# test: (708420, 38)
# train: (708405, 38)
# test: (708420, 38)
# train: (708405, 38)
# ./memory_item/SMD_memory_item.pth
# loading memory item vectors trained from kmeans (for test phase)
# Loading checkpoint: checkpoints/SMD_checkpoint_second_train.pth
# ======================TEST MODE======================
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/loss.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='none' instead.
# ...
